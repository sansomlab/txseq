# %%
# %run /gfs/projects/proj002/code/init.ipy
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython
# set database db: /gfs/projects/proj002/analysis/single-cell/csvdb

# %%
statement = '''select * from qc_summary'''

#db = "/home/ssansom/ctest/csvdb"

df = PU.fetch_DataFrame(statement,db)

data = pd.melt(df,id_vars="cell")

data.head()
# Out:
#                              cell        variable     value
# 0  WTCHG_195106_701502.reconciled  fraction_spike  0.825869
# 1  WTCHG_195106_701503.reconciled  fraction_spike  0.183231
# 2  WTCHG_195106_701504.reconciled  fraction_spike  0.307632
# 3  WTCHG_195106_701505.reconciled  fraction_spike  0.585858
# 4  WTCHG_195106_701506.reconciled  fraction_spike  0.330859

# %%
# %%R -i data -w 800 -h 800
# require(scales)
#
# scientific_10 <- function(x) {
#
#   parse(text=gsub("e", " %*% 10^", scientific_format()(x)))
#
# }
#
# gp <- ggplot(data, aes(value)) + geom_histogram() + facet_wrap(~variable, scales="free")
# #gp <- gp + scale_x_continuous(label=scientific_10)
# gp <- gp + theme(axis.text.x=element_text(angle=90))
# gp <- gp + ggtitle("Post-mapping QC histograms\n")
# gp <- gp + ylab("no. cells") + xlab("value - fraction or count")
#
# print(gp)
# ggsave("post_mapping_qc.pdf", gp, device=cairo_pdf)
# Out:
# stat_bin: binwidth defaulted to range/30. Use 'binwidth = x' to adjust this.
# stat_bin: binwidth defaulted to range/30. Use 'binwidth = x' to adjust this.
# stat_bin: binwidth defaulted to range/30. Use 'binwidth = x' to adjust this.
# stat_bin: binwidth defaulted to range/30. Use 'binwidth = x' to adjust this.
# stat_bin: binwidth defaulted to range/30. Use 'binwidth = x' to adjust this.
# stat_bin: binwidth defaulted to range/30. Use 'binwidth = x' to adjust this.
# stat_bin: binwidth defaulted to range/30. Use 'binwidth = x' to adjust this.
# stat_bin: binwidth defaulted to range/30. Use 'binwidth = x' to adjust this.
# stat_bin: binwidth defaulted to range/30. Use 'binwidth = x' to adjust this.
# stat_bin: binwidth defaulted to range/30. Use 'binwidth = x' to adjust this.
# Saving 11.1 x 11.1 in image
# stat_bin: binwidth defaulted to range/30. Use 'binwidth = x' to adjust this.
# stat_bin: binwidth defaulted to range/30. Use 'binwidth = x' to adjust this.
# stat_bin: binwidth defaulted to range/30. Use 'binwidth = x' to adjust this.
# stat_bin: binwidth defaulted to range/30. Use 'binwidth = x' to adjust this.
# stat_bin: binwidth defaulted to range/30. Use 'binwidth = x' to adjust this.
# stat_bin: binwidth defaulted to range/30. Use 'binwidth = x' to adjust this.
# stat_bin: binwidth defaulted to range/30. Use 'binwidth = x' to adjust this.
# stat_bin: binwidth defaulted to range/30. Use 'binwidth = x' to adjust this.
# stat_bin: binwidth defaulted to range/30. Use 'binwidth = x' to adjust this.
# stat_bin: binwidth defaulted to range/30. Use 'binwidth = x' to adjust this.
